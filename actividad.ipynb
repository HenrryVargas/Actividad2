# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import pandas as pd

# %%
datos53EquinoccioPrimavera= pd.read_csv("53EquinoccioPrimavera\RME_402151514RMD00530000000_______P9.csv", header=None)
datos196SolsticioVerano = pd.read_csv("196SolsticioVerano\RME_414846256RMD01960000000_______P7.csv", header=None)
datos350EquinoccioOtono = pd.read_csv("350EquinoccioOtono\RME_428517516RMD03500000000_______P6.csv", header=None)
datos543SolsticioInvierno = pd.read_csv("543SolsticioInvierno\RME_445650976RMD05430000000_______P4.csv", header=None)
# Out:
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\3057840826.py:1: DtypeWarning: Columns (17,18,19,20,21,22,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos53EquinoccioPrimavera= pd.read_csv("53EquinoccioPrimavera\RME_402151514RMD00530000000_______P9.csv", header=None)
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\3057840826.py:2: DtypeWarning: Columns (17,18,19,20,21,22,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos196SolsticioVerano = pd.read_csv("196SolsticioVerano\RME_414846256RMD01960000000_______P7.csv", header=None)
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\3057840826.py:4: DtypeWarning: Columns (17,18,19,20,21,22,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos543SolsticioInvierno = pd.read_csv("543SolsticioInvierno\RME_445650976RMD05430000000_______P4.csv", header=None)

# %% [markdown]
# # 53 Equinoccio de primavera

# %%
# Equinoccio de Primavera
df53EquiPrima = pd.DataFrame()
df53EquiPrima['LMST']= datos53EquinoccioPrimavera[1].str.replace("00053M","")
df53EquiPrima['LMST'] = pd.to_datetime(df53EquiPrima['LMST'],format="%H:%M:%S.%f")
df53EquiPrima['PAtmof']= datos53EquinoccioPrimavera[37]

# set the index to be columns "LMST" and drop=True to avoid creating a new index
df53EquiPrima.set_index('LMST', drop=True, inplace=True)
df53EquiPrima.DatetimeIndex = df53EquiPrima.index.time # remove the date part
dfEquiPrima = df53EquiPrima.resample('5T').mean()
dfEquiPrima
# Out:
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\3943668516.py:9: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df53EquiPrima.DatetimeIndex = df53EquiPrima.index.time # remove the date part
#                          PAtmof
# LMST
# 1900-01-01 00:00:00  778.507605
# 1900-01-01 00:05:00  778.812624
# 1900-01-01 00:10:00  779.034030
# 1900-01-01 00:15:00  779.330466
# 1900-01-01 00:20:00  779.759049
# ...                         ...
# 1900-01-01 22:45:00         NaN
# 1900-01-01 22:50:00         NaN
# 1900-01-01 22:55:00         NaN
# 1900-01-01 23:00:00  777.537449
# 1900-01-01 23:05:00  777.625965
#
# [278 rows x 1 columns]

# %%
# Grafica de equinoccio de primavera

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np

fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(dfEquiPrima.index, dfEquiPrima['PAtmof'], color='blue', label='Equinoccio de Primavera')

# set x begin with 00:00 and end with 23:05
ax.set_xlim([dfEquiPrima.index[0], dfEquiPrima.index[-1]])
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=30))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax.set_xlabel('Tiempo (Hora:Minutos)')
# x label are overlapping, so rotate the labels
fig.autofmt_xdate()

ax.set_ylabel('Presión Atmosférica (mbar)')
ax.set_title('Equinoccio de Primavera')
ax.grid(True)
plt.show()

# %% [markdown]
# # 196 solsticio de Verano

# %%
# Solsticio de Verano
df196SolsVerano = pd.DataFrame()
df196SolsVerano['LMST']= datos196SolsticioVerano[1].str.replace("00196M","")
df196SolsVerano['LMST'] = pd.to_datetime(df196SolsVerano['LMST'],format="%H:%M:%S.%f")
df196SolsVerano['PAtmof']= datos196SolsticioVerano[37]

# set the index to be columns "LMST" and drop=True to avoid creating a new index
df196SolsVerano.set_index('LMST', drop=True, inplace=True)
df196SolsVerano.DatetimeIndex = df53EquiPrima.index.time # remove the date part
dfSolsVerano = df196SolsVerano.resample('5T').mean()
dfSolsVerano
# Out:
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\3151110850.py:9: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df196SolsVerano.DatetimeIndex = df53EquiPrima.index.time # remove the date part
#                          PAtmof
# LMST
# 1900-01-01 00:00:00  934.138797
# 1900-01-01 00:05:00  934.388571
# 1900-01-01 00:10:00         NaN
# 1900-01-01 00:15:00         NaN
# 1900-01-01 00:20:00         NaN
# ...                         ...
# 1900-01-01 22:45:00         NaN
# 1900-01-01 22:50:00         NaN
# 1900-01-01 22:55:00         NaN
# 1900-01-01 23:00:00  925.830148
# 1900-01-01 23:05:00  925.926316
#
# [278 rows x 1 columns]

# %%
# Grafica de solsticio de verano

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np

fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(dfSolsVerano.index, dfSolsVerano['PAtmof'], color='red', label='Solsticio de Verano')

# set x begin with 00:00 and end with 23:05
ax.set_xlim([dfSolsVerano.index[0], dfSolsVerano.index[-1]])
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=30))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax.set_xlabel('Tiempo (Hora:Minutos)')
# x label are overlapping, so rotate the labels
fig.autofmt_xdate()

ax.set_ylabel('Presión Atmosférica (mbar)')
ax.set_title('Solsticio de Verano')
ax.grid(True)
plt.show()

# %% [markdown]
# # 350 Equinoccio de Otoño

# %%
# Equinoccio de Otono
df350EquiOtono = pd.DataFrame()
df350EquiOtono['LMST']= datos350EquinoccioOtono[1].str.replace("00350M","")
df350EquiOtono['LMST'] = pd.to_datetime(df350EquiOtono['LMST'],format="%H:%M:%S.%f")
df350EquiOtono['PAtmof']= datos350EquinoccioOtono[37]

# set the index to be columns "LMST" and drop=True to avoid creating a new index
df350EquiOtono.set_index('LMST', drop=True, inplace=True)
df350EquiOtono.DatetimeIndex = df350EquiOtono.index.time # remove the date part
dfEquiOtono = df350EquiOtono.resample('5T').mean()
dfEquiOtono
# Out:
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\2201180496.py:9: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df350EquiOtono.DatetimeIndex = df350EquiOtono.index.time # remove the date part
#                          PAtmof
# LMST
# 1900-01-01 00:00:00  869.347038
# 1900-01-01 00:05:00  869.404167
# 1900-01-01 00:10:00         NaN
# 1900-01-01 00:15:00         NaN
# 1900-01-01 00:20:00         NaN
# ...                         ...
# 1900-01-01 22:45:00         NaN
# 1900-01-01 22:50:00         NaN
# 1900-01-01 22:55:00         NaN
# 1900-01-01 23:00:00  857.918097
# 1900-01-01 23:05:00  858.263000
#
# [278 rows x 1 columns]

# %%
# Grafica de equinoccio de otono

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np

fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(dfEquiOtono.index, dfEquiOtono['PAtmof'], color='green', label='Equinoccio de Otoño')

# set x begin with 00:00 and end with 23:05
ax.set_xlim([dfEquiOtono.index[0], dfEquiOtono.index[-1]])
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=30))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax.set_xlabel('Tiempo (Hora:Minutos)')
# x label are overlapping, so rotate the labels
fig.autofmt_xdate()

ax.set_ylabel('Presión Atmosférica (mbar)')
ax.set_title('Equinoccio de Otoño')
ax.grid(True)
plt.show()

# %% [markdown]
# # 543 Solsticio de Invierno

# %%
# Solsticio de Invierno
df543SolsInvierno = pd.DataFrame()
df543SolsInvierno['LMST']= datos543SolsticioInvierno[1].str.replace("00543M","")
df543SolsInvierno['LMST'] = pd.to_datetime(df543SolsInvierno['LMST'],format="%H:%M:%S.%f")
df543SolsInvierno['PAtmof']= datos543SolsticioInvierno[37]

# set the index to be columns "LMST" and drop=True to avoid creating a new index
df543SolsInvierno.set_index('LMST', drop=True, inplace=True)
df543SolsInvierno.DatetimeIndex = df543SolsInvierno.index.time # remove the date part
dfSolsInvierno = df543SolsInvierno.resample('5T').mean()
dfSolsInvierno
# Out:
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\2295010958.py:9: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df543SolsInvierno.DatetimeIndex = df543SolsInvierno.index.time # remove the date part
#                          PAtmof
# LMST
# 1900-01-01 00:00:00  874.696136
# 1900-01-01 00:05:00  874.724773
# 1900-01-01 00:10:00         NaN
# 1900-01-01 00:15:00         NaN
# 1900-01-01 00:20:00         NaN
# ...                         ...
# 1900-01-01 22:45:00         NaN
# 1900-01-01 22:50:00         NaN
# 1900-01-01 22:55:00         NaN
# 1900-01-01 23:00:00  868.687490
# 1900-01-01 23:05:00  868.928113
#
# [278 rows x 1 columns]

# %%
# Grafica de solsticio de invierno

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np

fig, ax = plt.subplots(figsize=(15, 5))
ax.plot(dfSolsInvierno.index, dfSolsInvierno['PAtmof'], color='orange', label='Solsticio de Invierno')

# set x begin with 00:00 and end with 23:05
ax.set_xlim([dfSolsInvierno.index[0], dfSolsInvierno.index[-1]])
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=30))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax.set_xlabel('Tiempo (Hora:Minutos)')
# x label are overlapping, so rotate the labels
fig.autofmt_xdate()

ax.set_ylabel('Presión Atmosférica (mbar)')
ax.set_title('Solsticio de Invierno')
ax.grid(True)
plt.show()

# %% [markdown]
# # Graficar todas las estaciones

# %%
# Grafica de Equinoccio de Primavera, Solsticio de Verano, Equinoccio de Otoño y Solsticio de Invierno

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
import numpy as np

fig, ax = plt.subplots(figsize=(15, 10))
ax.plot(dfEquiPrima.index, dfEquiPrima['PAtmof'], color='blue', label='Equinoccio de Primavera')
ax.plot(dfSolsVerano.index, dfSolsVerano['PAtmof'], color='red', label='Solsticio de Verano')
ax.plot(dfEquiOtono.index, dfEquiOtono['PAtmof'], color='green', label='Equinoccio de Otoño')
ax.plot(dfSolsInvierno.index, dfSolsInvierno['PAtmof'], color='orange', label='Solsticio de Invierno')

# set x begin with 00:00 and end with 23:05
ax.set_xlim([dfEquiPrima.index[0], dfEquiPrima.index[-1]])
ax.xaxis.set_major_locator(mdates.MinuteLocator(interval=30))
ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%M'))
ax.set_xlabel('Tiempo (Hora:Minutos)')
# x label are overlapping, so rotate the labels
fig.autofmt_xdate()

ax.set_ylabel('Presión Atmosférica (mbar)')
ax.set_title('Presión Atmosférica tomada de REMS')

ax.legend(loc='upper right')
plt.show()
plt.savefig('PresionAtmosferica.png')

# %%
# combinar los datos de los 4 archivos en un solo dataframe y crear una descripcion atmofesrica de marte

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from astropy import units as u
from astropy.time import Time
from astropy.coordinates import SkyCoord, EarthLocation, AltAz

datos53EquinoccioPrimavera= pd.read_csv("53EquinoccioPrimavera\RME_402151514RMD00530000000_______P9.csv", header=None)
datos196SolsticioVerano = pd.read_csv("196SolsticioVerano\RME_414846256RMD01960000000_______P7.csv", header=None)
datos350EquinoccioOtono = pd.read_csv("350EquinoccioOtono\RME_428517516RMD03500000000_______P6.csv", header=None)
datos543SolsticioInvierno = pd.read_csv("543SolsticioInvierno\RME_445650976RMD05430000000_______P4.csv", header=None)

df53EquiPrima = pd.DataFrame()
df53EquiPrima['LMST']= datos53EquinoccioPrimavera[1].str.replace("00053M","")
df53EquiPrima['LMST'] = pd.to_datetime(df53EquiPrima['LMST'],format="%H:%M:%S.%f")
df53EquiPrima['PAtmof']= datos53EquinoccioPrimavera[37]
df53EquiPrima.set_index('LMST', drop=True, inplace=True)
df53EquiPrima.DatetimeIndex = df53EquiPrima.index.time # remove the date part
dfEquiPrima = df53EquiPrima.resample('5T').mean()

df196SolsVerano = pd.DataFrame()
df196SolsVerano['LMST']= datos196SolsticioVerano[1].str.replace("00196M","")
df196SolsVerano['LMST'] = pd.to_datetime(df196SolsVerano['LMST'],format="%H:%M:%S.%f")
df196SolsVerano['PAtmof']= datos196SolsticioVerano[37]
df196SolsVerano.set_index('LMST', drop=True, inplace=True)
df196SolsVerano.DatetimeIndex = df53EquiPrima.index.time # remove the date part
dfSolsVerano = df196SolsVerano.resample('5T').mean()

df350EquiOtono = pd.DataFrame()
df350EquiOtono['LMST']= datos350EquinoccioOtono[1].str.replace("00350M","")
df350EquiOtono['LMST'] = pd.to_datetime(df350EquiOtono['LMST'],format="%H:%M:%S.%f")
df350EquiOtono['PAtmof']= datos350EquinoccioOtono[37]
df350EquiOtono.set_index('LMST', drop=True, inplace=True)
df350EquiOtono.DatetimeIndex = df350EquiOtono.index.time # remove the date part
dfEquiOtono = df350EquiOtono.resample('5T').mean()

df543SolsInvierno = pd.DataFrame()
df543SolsInvierno['LMST']= datos543SolsticioInvierno[1].str.replace("00543M","")
df543SolsInvierno['LMST'] = pd.to_datetime(df543SolsInvierno['LMST'],format="%H:%M:%S.%f")
df543SolsInvierno['PAtmof']= datos543SolsticioInvierno[37]
df543SolsInvierno.set_index('LMST', drop=True, inplace=True)
df543SolsInvierno.DatetimeIndex = df543SolsInvierno.index.time # remove the date part
dfSolsInvierno = df543SolsInvierno.resample('5T').mean()

dfEquiPrima['Equinoccio de Primavera'] = dfEquiPrima['PAtmof']
dfEquiPrima['Solsticio de Verano'] = dfSolsVerano['PAtmof']
dfEquiPrima['Equinoccio de Otoño'] = dfEquiOtono['PAtmof']
dfEquiPrima['Solsticio de Invierno'] = dfSolsInvierno['PAtmof']
dfEquiPrima = dfEquiPrima.drop(columns=['PAtmof'])

dfEquiPrima.describe()
# Out:
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\1144770050.py:12: DtypeWarning: Columns (17,18,19,20,21,22,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos53EquinoccioPrimavera= pd.read_csv("53EquinoccioPrimavera\RME_402151514RMD00530000000_______P9.csv", header=None)
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\1144770050.py:13: DtypeWarning: Columns (17,18,19,20,21,22,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos196SolsticioVerano = pd.read_csv("196SolsticioVerano\RME_414846256RMD01960000000_______P7.csv", header=None)
# C:\Users\henrr\AppData\Local\Temp\ipykernel_23472\1144770050.py:15: DtypeWarning: Columns (17,18,19,20,21,22,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos543SolsticioInvierno = pd.read_csv("543SolsticioInvierno\RME_445650976RMD05430000000_______P4.csv", header=None)
# ...
